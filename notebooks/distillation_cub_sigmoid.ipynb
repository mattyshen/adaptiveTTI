# %%
import os
import matplotlib.pyplot as plt
import seaborn as sns
from os.path import join
from tqdm import tqdm
import pandas as pd
import numpy as np
import joblib
import imodelsx.process_results
import sys
from sklearn.metrics import accuracy_score

sys.path.append('../experiments/')
results = []

results_dir = f'../results/distillation_cub/cub_sigmoid'
experiment_filename = '../experiments/distillation_cub_sigmoid.py'

# load the results in to a pandas dataframe
r = imodelsx.process_results.get_results_df(results_dir)
cols_varied = imodelsx.process_results.get_experiment_keys(
    r, experiment_filename)
print('experiment varied these params:', cols_varied)
r = imodelsx.process_results.fill_missing_args_with_default(
    r, experiment_filename)

# save results as csvs for backup
r.to_csv('../csv_results/distillation_cub_sigmoid.csv')

# get the breakdown of data in these groups
r.groupby(cols_varied).size()
# Out:
# 100%|████████████████████████████████████████████| 3/3 [00:00<00:00, 604.98it/s]
# experiment varied these params: ['teacher_path', 'gpu']
# teacher_path                                gpu
# cub_sigmoid/outputs/best_model_large_1.pth  0      1
# cub_sigmoid/outputs/best_model_med_1.pth    1      1
# cub_sigmoid/outputs/best_model_small_1.pth  2      1
# dtype: int64

# %%
r[['teacher_path', 'student_distillation_test_accuracy','student_prediction_test_accuracy',
   'teacher_prediction_test_accuracy',
       'student_distillation_adap_interv_test_accuracy',
       'student_prediction_adap_interv_test_accuracy',
       'teacher_prediction_adap_interv_test_accuracy',
       'student_distillation_rand_interv_test_accuracy',
       'student_prediction_rand_interv_test_accuracy',
       'teacher_prediction_rand_interv_test_accuracy']]
# Out:
#                                  teacher_path  \
# 0  cub_sigmoid/outputs/best_model_large_1.pth
# 1    cub_sigmoid/outputs/best_model_med_1.pth
# 2  cub_sigmoid/outputs/best_model_small_1.pth
#
#    student_distillation_test_accuracy  student_prediction_test_accuracy  \
# 0                            0.826372                          0.718329
# 1                            0.890404                          0.751640
# 2                            0.934070                          0.757508
#
#    teacher_prediction_test_accuracy  \
# 0                          0.774422
# 1                          0.774940
# 2                          0.770452
#
#    student_distillation_adap_interv_test_accuracy  \
# 0                                        0.788057
# 1                                        0.855195
# 2                                        0.915085
#
#    student_prediction_adap_interv_test_accuracy  \
# 0                                      0.737314
# 1                                      0.774940
# 2                                      0.793407
#
#    teacher_prediction_adap_interv_test_accuracy  \
# 0                                      0.799275
# 1                                      0.793752
# 2                                      0.791508
#
#    student_distillation_rand_interv_test_accuracy  \
# 0                                        0.818778
# 1                                        0.874525
# 2                                        0.928374
#
#    student_prediction_rand_interv_test_accuracy  \
# 0                                      0.722126
# 1                                      0.753193
# 2                                      0.764757
#
#    teacher_prediction_rand_interv_test_accuracy
# 0                                      0.784605
# 1                                      0.785295
# 2                                      0.782016

# %%
r[['teacher_path',
   'teacher_prediction_train_accuracy',
       'student_distillation_adap_interv_test_accuracy',
       'student_prediction_adap_interv_test_accuracy',
       'teacher_prediction_adap_interv_test_accuracy',
       'student_distillation_rand_interv_test_accuracy',
       'student_prediction_rand_interv_test_accuracy',
       'teacher_prediction_rand_interv_test_accuracy']]
# Out:
#                                  teacher_path  \
# 0  cub_sigmoid/outputs/best_model_large_1.pth
# 1    cub_sigmoid/outputs/best_model_med_1.pth
# 2  cub_sigmoid/outputs/best_model_small_1.pth
#
#    teacher_prediction_train_accuracy  \
# 0                           0.952874
# 1                           0.962567
# 2                           0.947694
#
#    student_distillation_adap_interv_test_accuracy  \
# 0                                        0.788057
# 1                                        0.855195
# 2                                        0.915085
#
#    student_prediction_adap_interv_test_accuracy  \
# 0                                      0.737314
# 1                                      0.774940
# 2                                      0.793407
#
#    teacher_prediction_adap_interv_test_accuracy  \
# 0                                      0.799275
# 1                                      0.793752
# 2                                      0.791508
#
#    student_distillation_rand_interv_test_accuracy  \
# 0                                        0.818778
# 1                                        0.874525
# 2                                        0.928374
#
#    student_prediction_rand_interv_test_accuracy  \
# 0                                      0.722126
# 1                                      0.753193
# 2                                      0.764757
#
#    teacher_prediction_rand_interv_test_accuracy
# 0                                      0.784605
# 1                                      0.785295
# 2                                      0.782016
