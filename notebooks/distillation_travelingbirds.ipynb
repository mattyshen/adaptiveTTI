# %%
import os
import matplotlib.pyplot as plt
import seaborn as sns
from os.path import join
from tqdm import tqdm
import pandas as pd
import numpy as np
import joblib
import imodelsx.process_results
import sys
from sklearn.metrics import accuracy_score

sys.path.append('../experiments/')
results = []

results_dir = f'../results/distillation_travelingbirds'
experiment_filename = '../experiments/distillation_travelingbirds.py'

# load the results in to a pandas dataframe
r = imodelsx.process_results.get_results_df(results_dir)
cols_varied = imodelsx.process_results.get_experiment_keys(
    r, experiment_filename)
print('experiment varied these params:', cols_varied)
r = imodelsx.process_results.fill_missing_args_with_default(
    r, experiment_filename)

# save results as csvs for backup
r.to_csv('../csv_results/distillation_travelingbirds.csv')

# get the breakdown of data in these groups
r.groupby(cols_varied).size()
# Out:
# 100%|████████████████████████████████████████████| 3/3 [00:00<00:00, 643.76it/s]
# experiment varied these params: ['teacher_path']
# teacher_path
# travelingbirds/outputs/best_Joint0.01_MLP1_model_1.pth      1
# travelingbirds/outputs/best_Joint0.01_MLP2_model_1.pth      1
# travelingbirds/outputs/best_Joint0.01_linear_model_1.pth    1
# dtype: int64

# %%
r.loc[~r.isna().n_trees, ~r.columns.str.contains('train')&~r.columns.str.contains('distillation')]
# Out:
#                                             save_dir  \
# 0  /home/mattyshen/DistillationEdit/results/disti...
# 1  /home/mattyshen/DistillationEdit/results/disti...
# 2  /home/mattyshen/DistillationEdit/results/disti...
#
#                                         teacher_path  \
# 0  travelingbirds/outputs/best_Joint0.01_MLP2_mod...
# 1  travelingbirds/outputs/best_Joint0.01_MLP1_mod...
# 2  travelingbirds/outputs/best_Joint0.01_linear_m...
#
#                                            test_path   task_type  \
# 0  /home/mattyshen/ConceptBottleneck/CUB_processe...  regression
# 1  /home/mattyshen/ConceptBottleneck/CUB_processe...  regression
# 2  /home/mattyshen/ConceptBottleneck/CUB_processe...  regression
#
#       student_name n_trees_list n_rules_list n_depth_list  \
# 0  FIGSRegressorCV     [30, 40]   [125, 200]          [4]
# 1  FIGSRegressorCV     [30, 40]   [125, 200]          [4]
# 2  FIGSRegressorCV     [30, 40]   [125, 200]          [4]
#
#   min_impurity_decrease_list  max_rules  ...  n_rules  \
# 0                        [0]        200  ...      200
# 1                        [0]        200  ...      200
# 2                        [0]        200  ...      200
#
#    student_prediction_test_accuracy teacher_prediction_test_accuracy  depth  \
# 0                          0.491025                         0.496030      3
# 1                          0.484467                         0.491716      3
# 2                          0.479462                         0.517777      3
#
#    student_prediction_adap_interv_test_accuracy  \
# 0                                      0.598895
# 1                                      0.600621
# 2                                      0.607870
#
#    teacher_prediction_adap_interv_test_accuracy  \
# 0                                      0.526061
# 1                                      0.540041
# 2                                      0.592337
#
#   student_prediction_rand_interv_test_accuracy  \
# 0                                     0.514325
# 1                                     0.508975
# 2                                     0.507767
#
#    teacher_prediction_rand_interv_test_accuracy  \
# 0                                      0.498619
# 1                                      0.507594
# 2                                      0.549879
#
#    student_prediction_lin_interv_test_accuracy  \
# 0                                          NaN
# 1                                          NaN
# 2                                     0.480152
#
#    teacher_prediction_lin_interv_test_accuracy
# 0                                          NaN
# 1                                          NaN
# 2                                     0.498447
#
# [3 rows x 28 columns]
