# %%
import os
import matplotlib.pyplot as plt
import seaborn as sns
from os.path import join
from tqdm import tqdm
import pandas as pd
import numpy as np
import joblib
import imodelsx.process_results
import sys
sys.path.append('../experiments/')
results = []
for model in ['rf', 'figs', 'xgb', 'ftd']:
    results_dir = f'../results/07_cv_train_model/{model}'
    experiment_filename = '../experiments/07_cv_train_model.py'

    # load the results in to a pandas dataframe
    r = imodelsx.process_results.get_results_df(results_dir)
    cols_varied = imodelsx.process_results.get_experiment_keys(
        r, experiment_filename)
    print('experiment varied these params:', cols_varied)
    r = imodelsx.process_results.fill_missing_args_with_default(
        r, experiment_filename)
    results.append(r)

# get the breakdown of data in these groups
r = pd.concat(results, axis = 0)
r.groupby(cols_varied).size()
# Out:
# 100%|█████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 21/21 [00:00<00:00, 1002.99it/s]
# experiment varied these params: ['dataset_name', 'model_name', 'max_depth', 'max_features']
# 100%|█████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 32/32 [00:00<00:00, 1448.53it/s]
# experiment varied these params: ['dataset_name', 'max_rules', 'max_trees']
# 100%|█████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 16/16 [00:00<00:00, 1459.90it/s]
# experiment varied these params: ['dataset_name', 'max_depth']
# 100%|█████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 21/21 [00:00<00:00, 1424.53it/s]
# experiment varied these params: ['dataset_name', 'binary_mapper_name', 'binary_mapper_depth']
# dataset_name   binary_mapper_name  binary_mapper_depth
# abalone        dt_binary_mapper    2                       1
#                                    3                       1
#                gmm_binary_mapper   2                       1
#                no_binary_mapper    2                      14
# airfoil        dt_binary_mapper    2                       1
#                                    3                       1
#                gmm_binary_mapper   2                       1
#                no_binary_mapper    2                       7
# ca_housing     dt_binary_mapper    2                       1
#                                    3                       1
#                gmm_binary_mapper   2                       1
#                no_binary_mapper    2                      14
# concrete       dt_binary_mapper    2                       1
#                                    3                       1
#                gmm_binary_mapper   2                       1
#                no_binary_mapper    2                       6
# cpu_act        dt_binary_mapper    2                       1
#                gmm_binary_mapper   2                       1
#                no_binary_mapper    2                       6
# miami_housing  gmm_binary_mapper   2                       1
#                no_binary_mapper    2                       6
# parkinsons     dt_binary_mapper    2                       1
#                                    3                       1
#                gmm_binary_mapper   2                       1
#                no_binary_mapper    2                      10
# powerplant     dt_binary_mapper    2                       1
#                                    3                       1
#                gmm_binary_mapper   2                       1
#                no_binary_mapper    2                       6
# dtype: int64

# %%
r.to_csv('
# Out:
#      dataset_name  subsample_frac  seed  \
# 0         abalone            0.25     0
# 1         airfoil            0.25     0
# 2         abalone            0.25     0
# 3      ca_housing            0.25     0
# 4      ca_housing            0.25     0
# ..            ...             ...   ...
# 16       concrete            0.25     0
# 17        abalone            0.25     0
# 18        cpu_act            0.25     0
# 19        airfoil            0.25     0
# 20  miami_housing            0.25     0
#
#                                              save_dir     model_name  \
# 0   /home/mattyshen/interpretableDistillation/resu...  random_forest
# 1   /home/mattyshen/interpretableDistillation/resu...  random_forest
# 2   /home/mattyshen/interpretableDistillation/resu...        rf_plus
# 3   /home/mattyshen/interpretableDistillation/resu...        rf_plus
# 4   /home/mattyshen/interpretableDistillation/resu...  random_forest
# ..                                                ...            ...
# 16  /home/mattyshen/interpretableDistillation/resu...     ft_distill
# 17  /home/mattyshen/interpretableDistillation/resu...     ft_distill
# 18  /home/mattyshen/interpretableDistillation/resu...     ft_distill
# 19  /home/mattyshen/interpretableDistillation/resu...     ft_distill
# 20  /home/mattyshen/interpretableDistillation/resu...     ft_distill
#
#    binary_mapper_name  binary_mapper_bit  binary_mapper_depth  \
# 0    no_binary_mapper                  0                    2
# 1    no_binary_mapper                  0                    2
# 2    no_binary_mapper                  0                    2
# 3    no_binary_mapper                  0                    2
# 4    no_binary_mapper                  0                    2
# ..                ...                ...                  ...
# 16   dt_binary_mapper                  0                    2
# 17   dt_binary_mapper                  0                    2
# 18   dt_binary_mapper                  0                    2
# 19  gmm_binary_mapper                  0                    2
# 20  gmm_binary_mapper                  0                    2
#
#     binary_mapper_frac  max_depth  ...  n_epochs  gpu  use_cache  \
# 0                  0.5          4  ...       100    2          1
# 1                  0.5          4  ...       100    2          1
# 2                  0.5          4  ...       100    2          1
# 3                  0.5          4  ...       100    2          1
# 4                  0.5          5  ...       100    2          1
# ..                 ...        ...  ...       ...  ...        ...
# 16                 0.5          4  ...       100    2          1
# 17                 0.5          4  ...       100    2          1
# 18                 0.5          4  ...       100    2          1
# 19                 0.5          4  ...       100    2          1
# 20                 0.5          4  ...       100    2          1
#
#                                          cat_mappings   task_type  \
# 0                   {'Sex': {'F': 0, 'I': 1, 'M': 2}}  regression
# 1   {'chord-length': {'0.0254': 0, '0.0508': 1, '0...  regression
# 2                   {'Sex': {'F': 0, 'I': 1, 'M': 2}}  regression
# 3                                                  {}  regression
# 4                                                  {}  regression
# ..                                                ...         ...
# 16                                                 {}  regression
# 17                  {'Sex': {'F': 0, 'I': 1, 'M': 2}}  regression
# 18                                                 {}  regression
# 19  {'chord-length': {'0.0254': 0, '0.0508': 1, '0...  regression
# 20  {'avno60plus': {'0.0': 0, '1.0': 1}, 'month_so...  regression
#
#                                       save_dir_unique  \
# 0   /home/mattyshen/interpretableDistillation/resu...
# 1   /home/mattyshen/interpretableDistillation/resu...
# 2   /home/mattyshen/interpretableDistillation/resu...
# 3   /home/mattyshen/interpretableDistillation/resu...
# 4   /home/mattyshen/interpretableDistillation/resu...
# ..                                                ...
# 16  /home/mattyshen/interpretableDistillation/resu...
# 17  /home/mattyshen/interpretableDistillation/resu...
# 18  /home/mattyshen/interpretableDistillation/resu...
# 19  /home/mattyshen/interpretableDistillation/resu...
# 20  /home/mattyshen/interpretableDistillation/resu...
#
#     teacher_avg_kfold_val_r2  \
# 0                   0.490742
# 1                   0.624176
# 2                   0.554883
# 3                   0.488758
# 4                   0.680557
# ..                       ...
# 16                  0.690408
# 17                  0.372679
# 18                  0.939112
# 19                  0.549698
# 20                  0.783915
#
#                                  teacher_kfold_val_r2  \
# 0   [0.4672065162577933, 0.48987065900470805, 0.51...
# 1   [0.5795194395524845, 0.6262160990675844, 0.666...
# 2   [0.5127193656127655, 0.549305457983629, 0.6026...
# 3   [0.6382671613570867, 0.19241838794050337, 0.63...
# 4   [0.6828410729210146, 0.6786852655716229, 0.680...
# ..                                                ...
# 16  [0.66771793385508, 0.6577942685690668, 0.74571...
# 17  [0.3554607402091743, 0.3566562682983969, 0.405...
# 18  [0.9208508900026702, 0.9537978876394451, 0.942...
# 19  [0.5054820310749297, 0.6383697344246079, 0.505...
# 20  [0.8002162605245127, 0.7883267943196921, 0.763...
#
#     teacher_r2_score_train_true  teacher_r2_score_val_true
# 0                      0.549257                   0.480989
# 1                      0.686833                   0.619197
# 2                      0.579768                   0.523940
# 3                      0.635886                   0.589175
# 4                      0.697521                   0.652106
# ..                          ...                        ...
# 16                     0.786607                   0.811876
# 17                     0.407586                   0.375404
# 18                     0.959264                   0.948353
# 19                     0.700653                   0.643415
# 20                     0.827269                   0.782725
#
# [90 rows x 28 columns]

# %%
r[r['model_name'] == 'ft_distill']
# Out:
#      dataset_name  subsample_frac  seed  \
# 0        concrete            0.25     0
# 1         abalone            0.25     0
# 2        concrete            0.25     0
# 3         cpu_act            0.25     0
# 4      ca_housing            0.25     0
# 5      powerplant            0.25     0
# 6         cpu_act            0.25     0
# 7      parkinsons            0.25     0
# 8   miami_housing            0.25     0
# 9      ca_housing            0.25     0
# 10     powerplant            0.25     0
# 11     parkinsons            0.25     0
# 12        abalone            0.25     0
# 13        airfoil            0.25     0
# 14  miami_housing            0.25     0
# 15        airfoil            0.25     0
#
#                                              save_dir  model_name  \
# 0   /home/mattyshen/interpretableDistillation/resu...  ft_distill
# 1   /home/mattyshen/interpretableDistillation/resu...  ft_distill
# 2   /home/mattyshen/interpretableDistillation/resu...  ft_distill
# 3   /home/mattyshen/interpretableDistillation/resu...  ft_distill
# 4   /home/mattyshen/interpretableDistillation/resu...  ft_distill
# 5   /home/mattyshen/interpretableDistillation/resu...  ft_distill
# 6   /home/mattyshen/interpretableDistillation/resu...  ft_distill
# 7   /home/mattyshen/interpretableDistillation/resu...  ft_distill
# 8   /home/mattyshen/interpretableDistillation/resu...  ft_distill
# 9   /home/mattyshen/interpretableDistillation/resu...  ft_distill
# 10  /home/mattyshen/interpretableDistillation/resu...  ft_distill
# 11  /home/mattyshen/interpretableDistillation/resu...  ft_distill
# 12  /home/mattyshen/interpretableDistillation/resu...  ft_distill
# 13  /home/mattyshen/interpretableDistillation/resu...  ft_distill
# 14  /home/mattyshen/interpretableDistillation/resu...  ft_distill
# 15  /home/mattyshen/interpretableDistillation/resu...  ft_distill
#
#    binary_mapper_name  binary_mapper_bit  binary_mapper_depth  \
# 0   gmm_binary_mapper                  0                    2
# 1   gmm_binary_mapper                  0                    3
# 2   gmm_binary_mapper                  0                    3
# 3   gmm_binary_mapper                  0                    2
# 4   gmm_binary_mapper                  0                    2
# 5   gmm_binary_mapper                  0                    2
# 6   gmm_binary_mapper                  0                    3
# 7   gmm_binary_mapper                  0                    3
# 8   gmm_binary_mapper                  0                    3
# 9   gmm_binary_mapper                  0                    3
# 10  gmm_binary_mapper                  0                    3
# 11  gmm_binary_mapper                  0                    2
# 12  gmm_binary_mapper                  0                    2
# 13  gmm_binary_mapper                  0                    2
# 14  gmm_binary_mapper                  0                    2
# 15  gmm_binary_mapper                  0                    3
#
#     binary_mapper_frac  max_depth  ...  n_epochs  gpu  use_cache  \
# 0                  0.5          4  ...       100    2          1
# 1                  0.5          4  ...       100    2          1
# 2                  0.5          4  ...       100    2          1
# 3                  0.5          4  ...       100    2          1
# 4                  0.5          4  ...       100    2          1
# 5                  0.5          4  ...       100    2          1
# 6                  0.5          4  ...       100    2          1
# 7                  0.5          4  ...       100    2          1
# 8                  0.5          4  ...       100    2          1
# 9                  0.5          4  ...       100    2          1
# 10                 0.5          4  ...       100    2          1
# 11                 0.5          4  ...       100    2          1
# 12                 0.5          4  ...       100    2          1
# 13                 0.5          4  ...       100    2          1
# 14                 0.5          4  ...       100    2          1
# 15                 0.5          4  ...       100    2          1
#
#                                          cat_mappings   task_type  \
# 0                                                  {}  regression
# 1                   {'Sex': {'F': 0, 'I': 1, 'M': 2}}  regression
# 2                                                  {}  regression
# 3                                                  {}  regression
# 4                                                  {}  regression
# 5                                                  {}  regression
# 6                                                  {}  regression
# 7                           {'sex': {'0': 0, '1': 1}}  regression
# 8   {'avno60plus': {'0.0': 0, '1.0': 1}, 'month_so...  regression
# 9                                                  {}  regression
# 10                                                 {}  regression
# 11                          {'sex': {'0': 0, '1': 1}}  regression
# 12                  {'Sex': {'F': 0, 'I': 1, 'M': 2}}  regression
# 13  {'chord-length': {'0.0254': 0, '0.0508': 1, '0...  regression
# 14  {'avno60plus': {'0.0': 0, '1.0': 1}, 'month_so...  regression
# 15  {'chord-length': {'0.0254': 0, '0.0508': 1, '0...  regression
#
#                                       save_dir_unique  \
# 0   /home/mattyshen/interpretableDistillation/resu...
# 1   /home/mattyshen/interpretableDistillation/resu...
# 2   /home/mattyshen/interpretableDistillation/resu...
# 3   /home/mattyshen/interpretableDistillation/resu...
# 4   /home/mattyshen/interpretableDistillation/resu...
# 5   /home/mattyshen/interpretableDistillation/resu...
# 6   /home/mattyshen/interpretableDistillation/resu...
# 7   /home/mattyshen/interpretableDistillation/resu...
# 8   /home/mattyshen/interpretableDistillation/resu...
# 9   /home/mattyshen/interpretableDistillation/resu...
# 10  /home/mattyshen/interpretableDistillation/resu...
# 11  /home/mattyshen/interpretableDistillation/resu...
# 12  /home/mattyshen/interpretableDistillation/resu...
# 13  /home/mattyshen/interpretableDistillation/resu...
# 14  /home/mattyshen/interpretableDistillation/resu...
# 15  /home/mattyshen/interpretableDistillation/resu...
#
#     teacher_avg_kfold_val_r2  \
# 0                   0.640654
# 1                   0.412915
# 2                   0.640654
# 3                   0.960070
# 4                   0.596783
# 5                   0.896023
# 6                   0.960070
# 7                   0.337352
# 8                   0.783915
# 9                   0.596783
# 10                  0.896023
# 11                  0.337352
# 12                  0.412915
# 13                  0.549698
# 14                  0.783915
# 15                  0.549698
#
#                                  teacher_kfold_val_r2  \
# 0   [0.5019443079479222, 0.7242467284275387, 0.695...
# 1   [0.4074576790172757, 0.39220587599145973, 0.43...
# 2   [0.5019443079479222, 0.7242467284275387, 0.695...
# 3   [0.9602567927643734, 0.9605258489973315, 0.959...
# 4   [0.5777872022192079, 0.5983047118387469, 0.614...
# 5   [0.9005213707340025, 0.8944348311628074, 0.893...
# 6   [0.9602567927643734, 0.9605258489973315, 0.959...
# 7   [0.3248962067347715, 0.33521836520979265, 0.35...
# 8   [0.8002162605245127, 0.7883267943196921, 0.763...
# 9   [0.5777872022192079, 0.5983047118387469, 0.614...
# 10  [0.9005213707340025, 0.8944348311628074, 0.893...
# 11  [0.3248962067347715, 0.33521836520979265, 0.35...
# 12  [0.4074576790172757, 0.39220587599145973, 0.43...
# 13  [0.5054820310749297, 0.6383697344246079, 0.505...
# 14  [0.8002162605245127, 0.7883267943196921, 0.763...
# 15  [0.5054820310749297, 0.6383697344246079, 0.505...
#
#     teacher_r2_score_train_true  teacher_r2_score_val_true
# 0                      0.558134                   0.587611
# 1                      0.445192                   0.426593
# 2                      0.558134                   0.587611
# 3                      0.963568                   0.964419
# 4                      0.616231                   0.611137
# 5                      0.898116                   0.903919
# 6                      0.963568                   0.964419
# 7                      0.418527                   0.409014
# 8                      0.827269                   0.782725
# 9                      0.616231                   0.611137
# 10                     0.898116                   0.903919
# 11                     0.418527                   0.409014
# 12                     0.445192                   0.426593
# 13                     0.700653                   0.643415
# 14                     0.827269                   0.782725
# 15                     0.700653                   0.643415
#
# [16 rows x 28 columns]

# %%
datasets = r['dataset_name'].unique()
datasets
# Out:
# array(['miami_housing', 'concrete', 'cpu_act', 'ca_housing', 'abalone',
#        'parkinsons', 'powerplant', 'airfoil'], dtype=object)

# %%
r.groupby(['dataset_name', 'binary_mapper_name'])[['teacher_r2_score_train_true', 'distiller_r2_score_train_true']].mean()
# Out:
#                                   teacher_r2_score_train_true  \
# dataset_name  binary_mapper_name
# abalone       dt_binary_mapper                       0.437893
#               gmm_binary_mapper                      0.452221
# airfoil       dt_binary_mapper                       0.640092
#               gmm_binary_mapper                      0.682041
# ca_housing    dt_binary_mapper                       0.634057
#               gmm_binary_mapper                      0.595615
# concrete      dt_binary_mapper                       0.784527
#               gmm_binary_mapper                      0.618321
# cpu_act       dt_binary_mapper                       0.946879
#               gmm_binary_mapper                      0.955843
# miami_housing dt_binary_mapper                       0.801075
#               gmm_binary_mapper                      0.806552
# parkinsons    dt_binary_mapper                       0.450965
#               gmm_binary_mapper                      0.426760
# powerplant    dt_binary_mapper                       0.909900
#               gmm_binary_mapper                      0.897767
#
#                                   distiller_r2_score_train_true
# dataset_name  binary_mapper_name
# abalone       dt_binary_mapper                         0.420869
#               gmm_binary_mapper                        0.444104
# airfoil       dt_binary_mapper                         0.582979
#               gmm_binary_mapper                        0.628718
# ca_housing    dt_binary_mapper                         0.616243
#               gmm_binary_mapper                        0.582795
# concrete      dt_binary_mapper                         0.745003
#               gmm_binary_mapper                        0.576028
# cpu_act       dt_binary_mapper                         0.936565
#               gmm_binary_mapper                        0.949414
# miami_housing dt_binary_mapper                         0.758434
#               gmm_binary_mapper                        0.780159
# parkinsons    dt_binary_mapper                         0.396563
#               gmm_binary_mapper                        0.358755
# powerplant    dt_binary_mapper                         0.908920
#               gmm_binary_mapper                        0.896867

# %%
r[(r['distiller_name']=='ft_distill') & (r['max_depth']==5) & (r['max_features']==0.75)] #['max_features'].value_counts()
# Out:
#       dataset_name  subsample_frac  seed  \
# 4          airfoil            0.25     0
# 11      ca_housing            0.25     0
# 15         airfoil            0.25     0
# 30         abalone            0.25     0
# 36        concrete            0.25     0
# 37      powerplant            0.25     0
# 60      ca_housing            0.25     0
# 65      powerplant            0.25     0
# 70   miami_housing            0.25     0
# 79      parkinsons            0.25     0
# 83         cpu_act            0.25     0
# 86         cpu_act            0.25     0
# 94         abalone            0.25     0
# 111  miami_housing            0.25     0
# 117     parkinsons            0.25     0
# 121       concrete            0.25     0
#
#                                               save_dir     model_name  \
# 4    /home/mattyshen/interpretableDistillation/resu...        rf_plus
# 11   /home/mattyshen/interpretableDistillation/resu...  random_forest
# 15   /home/mattyshen/interpretableDistillation/resu...  random_forest
# 30   /home/mattyshen/interpretableDistillation/resu...  random_forest
# 36   /home/mattyshen/interpretableDistillation/resu...  random_forest
# 37   /home/mattyshen/interpretableDistillation/resu...  random_forest
# 60   /home/mattyshen/interpretableDistillation/resu...        rf_plus
# 65   /home/mattyshen/interpretableDistillation/resu...        rf_plus
# 70   /home/mattyshen/interpretableDistillation/resu...        rf_plus
# 79   /home/mattyshen/interpretableDistillation/resu...  random_forest
# 83   /home/mattyshen/interpretableDistillation/resu...        rf_plus
# 86   /home/mattyshen/interpretableDistillation/resu...  random_forest
# 94   /home/mattyshen/interpretableDistillation/resu...        rf_plus
# 111  /home/mattyshen/interpretableDistillation/resu...  random_forest
# 117  /home/mattyshen/interpretableDistillation/resu...        rf_plus
# 121  /home/mattyshen/interpretableDistillation/resu...        rf_plus
#
#     distiller_name binary_mapper_name  binary_mapper_bit  binary_mapper_depth  \
# 4       ft_distill  gmm_binary_mapper                  0                    2
# 11      ft_distill  gmm_binary_mapper                  0                    2
# 15      ft_distill  gmm_binary_mapper                  0                    2
# 30      ft_distill  gmm_binary_mapper                  0                    2
# 36      ft_distill  gmm_binary_mapper                  0                    2
# 37      ft_distill  gmm_binary_mapper                  0                    2
# 60      ft_distill  gmm_binary_mapper                  0                    2
# 65      ft_distill  gmm_binary_mapper                  0                    2
# 70      ft_distill  gmm_binary_mapper                  0                    2
# 79      ft_distill  gmm_binary_mapper                  0                    2
# 83      ft_distill  gmm_binary_mapper                  0                    2
# 86      ft_distill  gmm_binary_mapper                  0                    2
# 94      ft_distill  gmm_binary_mapper                  0                    2
# 111     ft_distill  gmm_binary_mapper                  0                    2
# 117     ft_distill  gmm_binary_mapper                  0                    2
# 121     ft_distill  gmm_binary_mapper                  0                    2
#
#      binary_mapper_frac  ...  teacher_avg_kfold_val_r2  \
# 4                   0.5  ...                  0.631374
# 11                  0.5  ...                  0.575262
# 15                  0.5  ...                  0.565680
# 30                  0.5  ...                  0.430098
# 36                  0.5  ...                  0.653599
# 37                  0.5  ...                  0.899069
# 60                  0.5  ...                  0.605822
# 65                  0.5  ...                  0.901287
# 70                  0.5  ...                  0.797484
# 79                  0.5  ...                  0.376965
# 83                  0.5  ...                  0.967701
# 86                  0.5  ...                  0.957647
# 94                  0.5  ...                  0.431699
# 111                 0.5  ...                  0.770671
# 117                 0.5  ...                  0.383220
# 121                 0.5  ...                  0.727807
#
#      distiller_avg_kfold_val_r2  \
# 4                      0.528392
# 11                     0.566487
# 15                     0.517132
# 30                     0.428982
# 36                     0.618370
# 37                     0.895423
# 60                     0.600142
# 65                     0.895313
# 70                     0.779652
# 79                     0.290582
# 83                     0.962198
# 86                     0.952813
# 94                     0.428094
# 111                    0.756995
# 117                    0.305028
# 121                    0.655733
#
#                                   teacher_kfold_val_r2  \
# 4                                                  NaN
# 11                                                 NaN
# 15                                                 NaN
# 30                                                 NaN
# 36   [0.7372227345830917, 0.6649043348438697, 0.558...
# 37                                                 NaN
# 60                                                 NaN
# 65   [0.9050628931512072, 0.8984991547244284, 0.900...
# 70   [0.8026120954526661, 0.7851084411577665, 0.804...
# 79                                                 NaN
# 83   [0.9676088599065417, 0.9662151492309821, 0.969...
# 86                                                 NaN
# 94                                                 NaN
# 111                                                NaN
# 117                                                NaN
# 121  [0.76830407680131, 0.7393000404290843, 0.67581...
#
#                                 distiller_kfold_val_r2  \
# 4                                                  NaN
# 11                                                 NaN
# 15                                                 NaN
# 30                                                 NaN
# 36   [0.7214581841954872, 0.627435528244561, 0.5062...
# 37                                                 NaN
# 60                                                 NaN
# 65   [0.8980687820752135, 0.894362164807568, 0.8935...
# 70   [0.7873661989602345, 0.7657369356844356, 0.785...
# 79                                                 NaN
# 83   [0.9619249145110451, 0.9620312487471991, 0.962...
# 86                                                 NaN
# 94                                                 NaN
# 111                                                NaN
# 117                                                NaN
# 121  [0.7161499324009453, 0.7021208667274124, 0.548...
#
#     teacher_r2_score_train_true  teacher_r2_score_val_true  \
# 4                      0.723132                   0.636773
# 11                     0.571950                   0.559231
# 15                     0.675712                   0.580801
# 30                     0.449007                   0.460803
# 36                     0.635683                   0.628152
# 37                     0.899699                   0.903825
# 60                     0.607352                   0.599267
# 65                     0.900417                   0.904039
# 70                     0.816353                   0.770562
# 79                     0.409180                   0.409688
# 83                     0.970241                   0.970196
# 86                     0.961305                   0.962707
# 94                     0.449936                   0.461127
# 111                    0.796066                   0.741910
# 117                    0.419274                   0.413749
# 121                    0.640179                   0.655802
#
#     distiller_r2_score_train_true  distiller_r2_score_val_true  \
# 4                        0.659622                     0.576117
# 11                       0.563096                     0.553496
# 15                       0.617424                     0.533758
# 30                       0.440748                     0.455733
# 36                       0.593082                     0.612227
# 37                       0.895288                     0.900597
# 60                       0.599802                     0.592722
# 65                       0.894715                     0.898809
# 70                       0.787685                     0.745521
# 79                       0.343744                     0.354668
# 83                       0.966691                     0.967509
# 86                       0.958039                     0.960254
# 94                       0.441825                     0.456328
# 111                      0.768428                     0.724279
# 117                      0.371428                     0.357816
# 121                      0.601201                     0.644385
#
#      distiller_r2_score_train_teacher  distiller_r2_score_val_teacher
# 4                            0.954681                        0.945686
# 11                           0.994404                        0.993306
# 15                           0.953451                        0.943910
# 30                           0.990665                        0.988302
# 36                           0.959074                        0.959548
# 37                           0.997024                        0.996651
# 60                           0.993852                        0.993511
# 65                           0.995016                        0.994582
# 70                           0.985737                        0.984692
# 79                           0.886396                        0.878536
# 83                           0.998164                        0.997939
# 86                           0.998542                        0.998574
# 94                           0.994528                        0.993705
# 111                          0.982505                        0.981892
# 117                          0.925722                        0.913170
# 121                          0.979622                        0.984872
#
# [16 rows x 35 columns]

# %%
#RF params: max_depth, max_features
random_forest= r[r['model_name'] == 'random_forest'].drop(columns=['subsample_frac', 'save_dir', 'use_cache', 'cat_mappings', 'task_type', 'save_dir_unique',
                                                        'gpu', 'n_epochs', 'max_rules', 'max_trees', 'pre_interaction', 'post_interaction',
                                                        'pre_max_features', 'post_max_features', 'size_interactions'])
random_forest_g = random_forest.groupby(['dataset_name','model_name', 'max_depth', 'max_features', 'bit', 'depth'])[['teacher_r2_score_train_true', 'teacher_r2_score_val_true']].mean()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Input In [5], in <cell line: 5>()
#       1 #RF params: max_depth, max_features
#       2 random_forest= r[r['model_name'] == 'random_forest'].drop(columns=['subsample_frac', 'save_dir', 'use_cache', 'cat_mappings', 'task_type', 'save_dir_unique',
#       3                                                         'gpu', 'n_epochs', 'max_rules', 'max_trees', 'pre_interaction', 'post_interaction',
#       4                                                         'pre_max_features', 'post_max_features', 'size_interactions'])
# ----> 5 random_forest_g = random_forest.groupby(['dataset_name','model_name', 'max_depth', 'max_features', 'bit', 'depth'])[['teacher_r2_score_train_true', 'teacher_r2_score_val_true']].mean()
#
# File ~/anaconda3/lib/python3.9/site-packages/pandas/core/frame.py:9183, in DataFrame.groupby(self, by, axis, level, as_index, sort, group_keys, observed, dropna)
#    9180 if level is None and by is None:
#    9181     raise TypeError("You have to supply one of 'by' and 'level'")
# -> 9183 return DataFrameGroupBy(
#    9184     obj=self,
#    9185     keys=by,
#    9186     axis=axis,
#    9187     level=level,
#    9188     as_index=as_index,
#    9189     sort=sort,
#    9190     group_keys=group_keys,
#    9191     observed=observed,
#    9192     dropna=dropna,
#    9193 )
#
# File ~/anaconda3/lib/python3.9/site-packages/pandas/core/groupby/groupby.py:1329, in GroupBy.__init__(self, obj, keys, axis, level, grouper, exclusions, selection, as_index, sort, group_keys, observed, dropna)
#    1326 self.dropna = dropna
#    1328 if grouper is None:
# -> 1329     grouper, exclusions, obj = get_grouper(
#    1330         obj,
#    1331         keys,
#    1332         axis=axis,
#    1333         level=level,
#    1334         sort=sort,
#    1335         observed=False if observed is lib.no_default else observed,
#    1336         dropna=self.dropna,
#    1337     )
#    1339 if observed is lib.no_default:
#    1340     if any(ping._passed_categorical for ping in grouper.groupings):
#
# File ~/anaconda3/lib/python3.9/site-packages/pandas/core/groupby/grouper.py:1043, in get_grouper(obj, key, axis, level, sort, observed, validate, dropna)
#    1041         in_axis, level, gpr = False, gpr, None
#    1042     else:
# -> 1043         raise KeyError(gpr)
#    1044 elif isinstance(gpr, Grouper) and gpr.key is not None:
#    1045     # Add key to exclusions
#    1046     exclusions.add(gpr.key)
#
# KeyError: 'bit'

# %%
random_forest.groupby(['max_depth', 'max_features', 'seed']).count()

# %%
# random_forest_best_hyp = {}
# for d in datasets:
#     queried = random_forest_g.query(f"dataset_name == '{d}'")
#     d_best_hyp = dict(zip(['dataset_name','model_name', 'max_depth', 'max_features'], list(queried['r2_score_val_true'].idxmax())))
#     d_best_hyp['r2_val'] = queried['r2_score_val_true'].max()
#     del d_best_hyp['dataset_name']
#     del d_best_hyp['model_name']
#     random_forest_best_hyp[d] = d_best_hyp
# random_forest_best_hyp

# %%
#RF+ params: max_depth, max_features
rf_plus = r[r['model_name'] == 'rf_plus'].drop(columns=['subsample_frac', 'save_dir', 'use_cache', 'cat_mappings', 'task_type', 'save_dir_unique',
                                                        'gpu', 'n_epochs', 'max_rules', 'max_trees', 'pre_interaction', 'post_interaction',
                                                        'pre_max_features', 'post_max_features', 'size_interactions'])
rf_plus_g = rf_plus.groupby(['dataset_name','model_name', 'max_depth', 'max_features', 'bit', 'depth'])[['teacher_r2_score_train_true', 'teacher_r2_score_val_true']].mean()
rf_plus_g

# %%
rf_plus.groupby(['max_depth', 'max_features', 'seed']).count()

# %%
# rf_plus_best_hyp = {}
# for d in datasets:
#     queried = rf_plus_g.query(f"dataset_name == '{d}'")
#     d_best_hyp = dict(zip(['dataset_name','model_name', 'max_depth', 'max_features'], list(queried['r2_score_val_true'].idxmax())))
#     d_best_hyp['r2_val'] = queried['r2_score_val_true'].max()
#     del d_best_hyp['dataset_name']
#     del d_best_hyp['model_name']
#     rf_plus_best_hyp[d] = d_best_hyp
# rf_plus_best_hyp

# %%
#FIGS params: max_rules, max_trees, max_features
figs = r[r['model_name'] == 'figs'].drop(columns=['subsample_frac', 'save_dir', 'use_cache', 'cat_mappings', 'task_type', 'save_dir_unique',
                                                        'gpu', 'n_epochs', 'max_depth','pre_interaction', 'post_interaction',
                                                        'pre_max_features', 'post_max_features', 'size_interactions'])
figs_g = figs.groupby(['dataset_name','model_name', 'max_rules','max_trees', 'max_features', 'bit', 'depth'])[['teacher_r2_score_train_true', 'teacher_r2_score_val_true']].mean().round(2)
figs_g

# %%
figs.groupby(['max_rules', 'max_trees', 'max_features', 'seed']).count()

# %%
#RF+ params: max_depth, max_features
xgboost = r[r['model_name'] == 'xgboost'].drop(columns=['subsample_frac', 'save_dir','use_cache', 'cat_mappings', 'task_type', 'save_dir_unique',
                                                        'gpu', 'n_epochs', 'max_rules', 'max_trees', 'pre_interaction', 'post_interaction',
                                                        'pre_max_features', 'post_max_features', 'size_interactions', 'max_features'])
xgboost_g = xgboost.groupby(['dataset_name','model_name', 'max_depth', 'bit', 'depth'])[['teacher_r2_score_train_true', 'teacher_r2_score_val_true']].mean().round(2)
xgboost_g

# %%
xgboost.groupby(['max_depth', 'seed']).count()

# %%
# xgboost_best_hyp = {}
# for d in datasets:
#     queried = xgboost_g.query(f"dataset_name == '{d}'")
#     d_best_hyp = dict(zip(['dataset_name','model_name', 'max_depth'], list(queried['r2_score_val_true'].idxmax())))
#     d_best_hyp['r2_val'] = queried['r2_score_val_true'].max()
#     del d_best_hyp['dataset_name']
#     del d_best_hyp['model_name']
#     xgboost_best_hyp[d] = d_best_hyp
# xgboost_best_hyp

# %%
#ResNet params: n_epochs
resnet = r[r['model_name'] == 'resnet'].drop(columns=['subsample_frac', 'save_dir','use_cache', 'cat_mappings', 'task_type', 'save_dir_unique',
                                                        'gpu', 'max_rules', 'max_trees', 'pre_interaction', 'post_interaction',
                                                        'pre_max_features', 'post_max_features', 'size_interactions', 'max_features', 'max_depth'])
resnet_g = resnet.groupby(['dataset_name','model_name', 'n_epochs', 'bit', 'depth'])[['teacher_r2_score_train_true', 'teacher_r2_score_val_true']].mean()
resnet_g

# %%
resnet.groupby(['n_epochs', 'seed']).count()

# %%
# resnet_best_hyp = {}
# for d in resnet['dataset_name'].unique():
#     queried = resnet_g.query(f"dataset_name == '{d}'")
#     d_best_hyp = dict(zip(['dataset_name','model_name','n_epochs'], list(queried['r2_score_val_true'].idxmax())))
#     d_best_hyp['r2_val'] = queried['r2_score_val_true'].max()
#     del d_best_hyp['dataset_name']
#     del d_best_hyp['model_name']
#     resnet_best_hyp[d] = d_best_hyp
# resnet_best_hyp

# %%
#FT Transformer params: n_epochs
ft_transformer = r[r['model_name'] == 'ft_transformer'].drop(columns=['subsample_frac', 'save_dir', 'use_cache', 'cat_mappings', 'task_type', 'save_dir_unique',
                                                        'gpu', 'max_rules', 'max_trees', 'pre_interaction', 'post_interaction',
                                                        'pre_max_features', 'post_max_features', 'size_interactions', 'max_features', 'max_depth'])
ft_transformer_g = ft_transformer.groupby(['dataset_name','model_name', 'n_epochs', 'bit', 'depth'])[['teacher_r2_score_train_true', 'teacher_r2_score_val_true']].mean()
ft_transformer_g

# %%
ft_transformer.groupby(['n_epochs', 'seed']).count()

# %%
# ft_transformer_best_hyp = {}
# for d in ft_transformer['dataset_name'].unique():
#     queried = ft_transformer_g.query(f"dataset_name == '{d}'")
#     d_best_hyp = dict(zip(['dataset_name','model_name','n_epochs'], list(queried['r2_score_val_true'].idxmax())))
#     d_best_hyp['r2_val'] = queried['r2_score_val_true'].max()
#     del d_best_hyp['dataset_name']
#     del d_best_hyp['model_name']
#     ft_transformer_best_hyp[d] = d_best_hyp
# ft_transformer_best_hyp

# %%
best_hyp = {}
for m in ['random_forest', 'rf_plus', 'figs', 'xgboost', 'resnet', 'ft_transformer']:
    best_hyp[m] = eval(f'{m}_best_hyp')

# %%
import json 

class NpEncoder(json.JSONEncoder):
    def default(self, obj):
        if isinstance(obj, np.integer):
            return int(obj)
        if isinstance(obj, np.floating):
            return float(obj)
        if isinstance(obj, np.ndarray):
            return obj.tolist()
        return super(NpEncoder, self).default(obj)

with open('/home/mattyshen/interpretableDistillation/scripts/best_hyperparams/original_hyperparams.json', "w") as outfile: 
    json.dump(best_hyp, outfile, cls =NpEncoder)
